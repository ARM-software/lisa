# %%
import numpy as np
from scipy import stats as scipy_stats
from IPython.display import display
import ipywidgets as widgets
from IPython.display import clear_output
import pprint

pp = pprint.PrettyPrinter(indent=4)

# test result setup
# primary_score is the performance metric to compare
# valid_list is a list of metrics we need to all be present to be confident that this result is OK
# we also must have all 4 energy scores to be valid
#big_energy = 'BOARD_ENERGY_BIG'
#little_energy = 'BOARD_ENERGY_LITTLE'
#sys_energy = 'BOARD_ENERGY_SYS'
#gpu_energy = 'BOARD_ENERGY_GPU'
big_energy = 'a57_cenr'
little_energy = 'a53_cenr'
sys_energy = 'sys_cenr'
gpu_energy = 'gpu_cenr'
total_energy = ( big_energy, little_energy, sys_energy, gpu_energy )
cpus_energy = ( big_energy, little_energy )

big_energy2 = 'scpi_sensors BOARD_ENERGY_BIG'
little_energy2 = 'scpi_sensors BOARD_ENERGY_LITTLE'
sys_energy2 = 'scpi_sensors BOARD_ENERGY_SYS'
gpu_energy2 = 'scpi_sensors BOARD_ENERGY_GPU'
total_energy2 = ( big_energy2, little_energy2, sys_energy2, gpu_energy2 )
cpus_energy2 = ( big_energy2, little_energy2 )

energy_map = { big_energy: big_energy2, little_energy: little_energy2, sys_energy: sys_energy2, gpu_energy: gpu_energy2,
               big_energy2: big_energy, little_energy2: little_energy, sys_energy2: sys_energy, gpu_energy2: gpu_energy }

interesting_results = (
  { 'name': 'nenamark2', 'energy_test':False, 'primary_score':'nenamark score',
    'interesting':('',), 'valid_list':('nenamark score', ) },
  { 'name': 'egypt_2.5.1_HD_off', 'energy_test':False, 'primary_score':'FPS_0',
    'interesting':('Frames_0',), 'valid_list':('FPS_0', ) },
  { 'name': 'egypt_2.5.1_HD_on', 'energy_test':False, 'primary_score':'FPS_0',
    'interesting':('Frames_0',), 'valid_list':('FPS_0', ) },
  { 'name': 't-rex_2.7.0_HD_off', 'energy_test':False, 'primary_score':'FPS_0',
    'interesting':('Frames_0',), 'valid_list':('FPS_0', ) },
  { 'name': 't-rex_2.7.0_HD_on', 'energy_test':False, 'primary_score':'FPS_0',
    'interesting':('Frames_0',), 'valid_list':('FPS_0', ) },
  { 'name': 'manhattan_on', 'energy_test':False, 'primary_score':'FPS_0',
    'interesting':('Frames_0',), 'valid_list':('FPS_0', ) },
  { 'name': 'manhattan_off', 'energy_test':False, 'primary_score':'FPS_0',
    'interesting':('Frames_0',), 'valid_list':('FPS_0', ) },
  { 'name': 'seemore', 'energy_test':False, 'primary_score':'FPS',
    'interesting':('frame_count', 'janks', 'not_at_vsync',), 'valid_list':('FPS',) },
  { 'name': 'andebench', 'energy_test':False, 'primary_score': 'AndEMark Native',
    'interesting':('AndEMark Java',), 'valid_list': ('AndEMark Native', 'AndEMark Java',) },
  { 'name': 'andebenchst', 'energy_test':False, 'primary_score': 'AndEMark Native',
    'interesting':('AndEMark Java',), 'valid_list': ('AndEMark Native', 'AndEMark Java',) },
  { 'name': 'caffeinemark', 'energy_test':False, 'primary_score': 'OverallScore',
    'interesting':('Sieve', 'Loop', 'Logic', 'String', 'Float', 'Method',), 'valid_list': ('OverallScore','Sieve', 'Loop', 'Logic', 'String', 'Float', 'Method') },
  { 'name': 'cfbench', 'energy_test':False, 'primary_score': 'overall_score',
    'interesting':('java_score', 'native_score',), 'valid_list': ('overall_score',) },
  { 'name': 'linpack', 'energy_test':False, 'primary_score': 'Linpack MT',
    'interesting':('Linpack ST',), 'valid_list': ('Linpack MT', 'Linpack ST',) },
  { 'name': 'quadrant', 'energy_test':False, 'primary_score': 'benchmark_score',
    'interesting':('benchmark_cpu_score', 'benchmark_memory_score', 'benchmark_io_score', 'benchmark_g2d_score', 'benchmark_g3d_score', ), 'valid_list': ('benchmark_score',) },
  { 'name': 'smartbench', 'energy_test':False, 'primary_score': 'Smartbench: valueGame',
    'interesting':('Smartbench: valueProd',), 'valid_list': ('Smartbench: valueGame', 'Smartbench: valueProd',) },
  { 'name': 'sqlitebm', 'energy_test':False, 'primary_score': 'execution_time',
    'interesting':('',), 'valid_list': ('execution_time',) },
  { 'name': 'bbench_with_audio', 'energy_test':True, 'primary_score': 'execution_time',
    'interesting':('Mean Latency',), 'valid_list': ('Mean Latency',) },
  { 'name': 'audio', 'energy_test':True, 'primary_score': 'execution_time',
    'interesting':('',), 'valid_list': ('execution_time',) },
  { 'name': 'browserlaunchx8', 'energy_test':True, 'primary_score': 'time',
    'interesting':('time sd',), 'valid_list': ('time',) },
    
)
# functions to deal with interesting_results list
def get_valid_metric_list(workload):
    valid_list=None
    for entry in interesting_results:
        if entry['name'] == workload:
            valid_list=entry['valid_list']
            break
    return valid_list

spec_id_metadata = { 'baseline': 'mp_a53bc' }

# database lookup functions

# how many results are present for a given combo
# returns the actual number
def number_iterations_present(db_conn, workload, spec_id, run_uuid):
    statement="SELECT count(iteration) FROM results WHERE workload=? AND spec_id=? AND run_uuid=? AND metric=\'execution_time\'"
    cur = db_conn.execute(statement,(workload, spec_id, run_uuid))
    return cur.fetchone()[0]

# does the given iteration have the correct metrics to be considered at least valid?
# returns True or False
def is_iteration_valid(db_conn, workload, spec_id, run_uuid, iteration):
    get_iteration="SELECT metric, iteration FROM results WHERE workload=? AND spec_id=? AND run_uuid=? AND iteration=?"
    valid_list = get_valid_metric_list(workload)
    count=0
    seen_energy=0
    if not valid_list:
        return False
    for row in db_conn.execute(get_iteration,(workload, spec_id, run_uuid, iteration)):
        metric = row[0]
        if metric in valid_list:
            count+=1
        if metric in total_energy or metric in total_energy2:
            seen_energy+=1
    if count==len(valid_list) and seen_energy==4:
        return True
    else:
        return False

def get_workload_list_from_database(db_conn):
    statement="SELECT label FROM workload_specs"
    workload_list=[]
    for row in db_conn.execute(statement):
        workload_list.append(row[0])
    return workload_list

def get_iteration_list_by_test_run(db_conn, workload, spec_id, run_uuid):
    get_iterations="SELECT iteration FROM results WHERE workload=? AND spec_id=? AND run_uuid=? AND metric=\'execution_time\'"
    iteration_list=[]
    for row in db_conn.execute(get_iterations, (workload, spec_id, run_uuid)):
        iteration_num=row[0]
        if is_iteration_valid(db_conn, workload, spec_id, run_uuid, iteration_num):
            iteration_list.append(row[0])
    return iteration_list

def get_metric_by_iteration_and_run(db_conn, workload, spec_id, run_uuid, iteration, metric):
    #print 'workload={} spec_id={} run_uuid={} iteration={} metric={}'.format(workload, spec_id, run_uuid, iteration, metric)
    statement='SELECT value FROM results WHERE workload=? AND spec_id=? AND run_uuid=? AND iteration=? AND metric=?'
    cur = db_conn.execute(statement, (workload, spec_id, run_uuid, iteration, metric))
    return cur.fetchone()[0]

# figure out the unique combinations of UID present (workload, spec_id and run_uuid) which indicate a set of test runs
# for a single configuration
def get_unique_combo_list_from_database(db_conn):
    statement="SELECT DISTINCT workload,spec_id,run_uuid FROM results"
    cur = db_conn.execute(statement)
    return cur.fetchall()

def get_energy_type(db_conn):
    statement="SELECT DISTINCT metric FROM results"
    for metric in db_conn.execute(statement):
        if big_energy in metric:
            return 1
    return 2
    
# functions handling results
    
# values is a list of test results for one metric from a set of test runs
# we want to return a list of mean, geometric mean, variance
def make_stats(values):
    val_float=np.array([float(x) for x in values])
    # geomean
    val_geomean = scipy_stats.mstats.gmean(val_float)
    return (val_float.mean(),val_geomean,val_float.std())

def get_iterations(db_vars, metrics, energy_metrics, primary, iteration_list, iteration_skip_list):
    d,w,s,r=db_vars
    runs = []
    if big_energy in energy_metrics:
        total_energy_list = total_energy
        cpus_energy_list = cpus_energy
    else:
        total_energy_list = total_energy2
        cpus_energy_list = cpus_energy2
    for iteration in iteration_list:
        iteration_metrics = dict()
        iteration_metrics['iteration'] = iteration
        iteration_metrics[primary] = get_metric_by_iteration_and_run(d,w,s,r, iteration, primary)
        for metric in metrics:
            iteration_metrics[metric] = get_metric_by_iteration_and_run(d,w,s,r, iteration, metric)
        for metric in energy_metrics:
            iteration_metrics[metric] = get_metric_by_iteration_and_run(d,w,s,r, iteration, metric)
        total_energy_accu = 0
        for metric in total_energy_list:
            total_energy_accu += float(iteration_metrics[metric])
        iteration_metrics['total_energy'] = total_energy_accu
        cpu_energy_accu = 0
        for metric in cpus_energy_list:
            cpu_energy_accu += float(iteration_metrics[metric])
        iteration_metrics['cpu_energy'] = cpu_energy_accu
        runs.append(iteration_metrics)
    return runs
    
# each workload reports the following structure:
# result is a dictionary, 'name', 'spec_id' and 'run_uuid' refer to the workload identifier
#   'runs' is an array where each element contains another dictionary containing the valid
#     results from the database for the chosen workload although it only contains the fields
#     marked as primary score, interesting or one of the energy counters
#   'primary' is the name of the metric used for primary score
#   'stats' is a dictionary of tuples containing mean, geomean and stdev for each metric measured, where metric name is the key
def get_workload_report(db_conn, label, workload, spec_id, run_uuid):
    result = { 'label': label, 'name': workload, 'spec_id': spec_id, 'run_uuid': run_uuid }
    # metrics we will report on are:
    metrics = ()
    if get_energy_type(db_conn) == 1:
        energy_metrics = total_energy
    else:
        energy_metrics = total_energy2
    for x in interesting_results:
        if x['name'] == workload:
            primary = x['primary_score']
            for item in x['interesting']:
                if len(item) > 0:
                    metrics = metrics+(item,)
            break
    iteration_list = get_iteration_list_by_test_run(db_conn, workload, spec_id, run_uuid)
    #pp.pprint(iteration_list)
    iteration_skip_list=[]
    runs = get_iterations((db_conn, workload, spec_id, run_uuid), metrics, energy_metrics, primary, iteration_list, iteration_skip_list)
    result['runs'] = runs
    stats = dict()
    skip_members = ( 'iteration', 'primary_name' )
    if len(result['runs']):
        for member in result['runs'][0]:
            if member in skip_members:
                continue
            values=[x.get(member) for x in result['runs']]
            stats[member]=make_stats(values)
    result['stats']=stats
    result['primary']=primary
    return result

def print_workload_report(report):
    pp.pprint(report)

# perform a kruskal-wallis one-way analysis of variance
# we are assuming that the populations are the same shape and any difference is from the spec used
# this tells us if we are looking at a real difference or not.
def is_significant(member, a, b):
    kr_H,kr_p=scipy_stats.kruskal([x.get(member) for x in a],[x.get(member) for x in b])
    return kr_H,kr_p
   
def compare_one_energy_metric(metric_name, reference, comparison):
    # total energy compared for the two tests
    if reference['stats'].get(metric_name):
        ref_mean, ref_geomean, ref_std = reference['stats'][metric_name]
        ref_metric_name = metric_name
    else:
        ref_mean, ref_geomean, ref_std = reference['stats'][energy_map[metric_name]]
        ref_metric_name = energy_map[metric_name]
    if comparison['stats'].get(metric_name):
        comp_mean, comp_geomean, comp_std = comparison['stats'][metric_name]
        comp_metric_name = metric_name
    else:
        comp_mean, comp_geomean, comp_std = comparison['stats'][energy_map[metric_name]]
        comp_metric_name = energy_map[metric_name]
    lowest = reference
    if ref_mean > comp_mean:
        lowest = comparison
    if ref_metric_name == comp_metric_name:
        metric_name = ref_metric_name
    else:
        metric_name = '{}({})'.format(ref_metric_name, comp_metric_name)
    print '{}: {},\'{}\' averaged less energy ({:.4f}J vs {:.4f}J) overall'.format(metric_name, lowest['spec_id'], lowest['label'], ref_mean, comp_mean)
    kr_H,kr_p=is_significant(metric_name,reference['runs'],comparison['runs'])
    if kr_p <=0.05:
        print '{}  This result is LIKELY reliable (p={:.4f})'.format(''.rjust(len(metric_name)), kr_p)
    else:
        print '{}  This result is NOT LIKELY reliable (p={:.4f})'.format(''.rjust(len(metric_name)), kr_p)
    print ''

def compare_one_metric(metric_name, reference, comparison):
    # total energy compared for the two tests
    ref_mean, ref_geomean, ref_std = reference['stats'][metric_name]
    comp_mean, comp_geomean, comp_std = comparison['stats'][metric_name]
    lowest = reference
    if ref_mean > comp_mean:
        lowest = comparison
    print '{}: {},\'{}\' averaged lower ({:.4f} vs {:.4f}) overall'.format(metric_name, lowest['spec_id'],lowest['label'], ref_mean, comp_mean)
    kr_H,kr_p=is_significant(metric_name,reference['runs'],comparison['runs'])
    if kr_p <=0.05:
        print '{}  This result is LIKELY reliable (p={:.4f})'.format(''.rjust(len(metric_name)), kr_p)
    else:
        print '{}  This result is NOT LIKELY reliable (p={:.4f})'.format(''.rjust(len(metric_name)), kr_p)
    print ''

# produce a comparison report of two workloads - reference and comparison. They should be the
# result from calling get_workload_report, and should be the same workload or this won't work
# and might not tell you
def compare_workload_reports(reference, comparison, lower_is_better):
    # compare the primary results of the two sets
    ref_mean, ref_geomean, ref_std = reference['stats'][reference['primary']]
    comp_mean, comp_geomean, comp_std = comparison['stats'][comparison['primary']]
    print "Comparing workload reports for",reference['name']
    print ""
    print "Reference is {} {} {}".format(reference['label'],reference['spec_id'],reference['run_uuid'])
    print "Comparison is {} {} {}".format(comparison['label'],comparison['spec_id'],comparison['run_uuid'])
    print ""
    print "Primary metric for comparison is \"{}\"".format(reference['primary'])
    compare_one_metric(reference['primary'], reference, comparison)
    print ""
    print '{0:44s} {1:24s} {2:24s}'.format(reference['primary'],'{}({})'.format(reference['spec_id'],reference['label']).rjust(24),'{}({})'.format(comparison['spec_id'],comparison['label']).rjust(24))
    print '{0:44s} {1:24.4f} {2:24.4f}'.format('mean',ref_mean,comp_mean)
    print '{0:44s} {1:24.4f} {2:24.4f}'.format('stdev',ref_std,comp_std)
    kr_H,kr_p=is_significant(reference['primary'],reference['runs'],comparison['runs'])
    if kr_p <=0.05:
        print 'This result is LIKELY reliable (p={0:.4f})'.format(kr_p)
    else:
        print 'This result is NOT LIKELY reliable (p={0:.4f})'.format(kr_p)
    
    print "\nEnergy Comparison\n"
    energy_list=[ 'total_energy', 'cpu_energy', little_energy, big_energy ]
    for item in energy_list:
        compare_one_energy_metric(item, reference, comparison)
    print ""
    print '{0:44s} {1:24s} {2:24s}'.format('metric','{}({})'.format(reference['spec_id'],reference['label']).rjust(24),'{}({})'.format(comparison['spec_id'],comparison['label']).rjust(24))
    for item in energy_list:
        if reference['stats'].get(item):
            # ref_item is in reference
            item_ref = item
            if comparison['stats'].get(item):
                item_com = item
            else:
                item_com = energy_map[item]
        else:
            item_ref = energy_map[item]
            if comparison['stats'].get(item):
                item_com = item
            else:
                item_com = energy_map[item]
        ref_mean, ref_geomean, ref_std=reference['stats'][item_ref]
        com_mean, com_geomean, com_std=comparison['stats'][item_com]
        if item_ref==item_com:
            item = item_ref
        else:
            item = '{}({})'.format(item_ref,item_com)
        print '{0:44s} {1:24.4f} {2:24.4f}'.format('{}(mean)'.format(item),ref_mean, com_mean)
        print '{0:44s} {1:24.4f} {2:24.4f}'.format('{}(stdev)'.format(item),ref_std, com_std)
    already_seen = ['iteration']
    already_seen.extend(energy_list)
    already_seen.append(reference['primary'])
    others=[]
    for item in reference['runs'][0].keys():
        if item not in already_seen:
            others.append(item)
    print '\n\nThere are {} other Interesting Scores:'.format(len(others))
    if not len(others):
        print "End of report."
        return
    for item in others:
        if 'ENERGY' in item.upper() or 'cenr' in item:
            compare_one_energy_metric(item, reference, comparison)
        else:
            compare_one_metric(item, reference, comparison)
    print ""
    print '{0:44s} {1:24s} {2:24s}'.format('metric','{}({})'.format(reference['spec_id'],reference['label']).rjust(24),'{}({})'.format(comparison['spec_id'],comparison['label']).rjust(24))
    for item in others:
        if 'ENERGY' in item.upper() or 'cenr' in item:
            if reference['stats'].get(item):
                # ref_item is in reference
                ref_item = item
                if comparison['stats'].get(item):
                    com_item = item
                else:
                    com_item = energy_map[item]
            else:
                ref_item = energy_map[item]
                if comparison['stats'].get(item):
                    com_item = item
                else:
                    com_item = energy_map[item]
        else:
            ref_item = item
            com_item = item
        ref_mean, ref_geomean, ref_std=reference['stats'][ref_item]
        com_mean, com_geomean, com_std=comparison['stats'][com_item]
        if ref_item == com_item:
            item_name = ref_item
        else:
            item_name = '{}({})'.format(ref_item, com_item)
        print '{0:44s} {1:24.4f} {2:24.4f}'.format(item_name+'(mean)',ref_mean, com_mean)
        print '{0:44s} {1:24.4f} {2:24.4f}'.format(item_name+'(stdev)',ref_std, com_std)
        
    return

# %%
label_a='hmp'
file_location_a='run1/results.sqlite'
label_b='old'
file_location_b='../WA_Reporting_WIP/results.missing_cpusets.sqlite'
# get the database loaded
import sqlite3
# to skip a database, make the connection a None
conA = sqlite3.connect(file_location_a)
conB = sqlite3.connect(file_location_b)
#conB = None

# %%
combos=[]
selector_combos=[]
if conA:
    result = get_unique_combo_list_from_database(conA)
    for res in result:
        combos.append(res)
        selector_combos.append(res[0]+', '+res[1]+', '+res[2]+', '+label_a) 

if conB:
    result = get_unique_combo_list_from_database(conB)
    for res in result:
        combos.append(res)
        selector_combos.append(res[0]+', '+res[1]+', '+res[2]+', '+label_b) 

w = widgets.Dropdown(
    options=selector_combos,
    description='Combination'
)
def show_report():
    global w
    clear_output()
    string = w.value
    workload,spec_id,run_uuid,label=tuple([ x.strip() for x in string.split(",") if x.strip() ])
    db = conA
    if label == label_b:
        db = conB
    print "get_workload_report db={} label={} workload={} spec_id={} run_uuid={}".format(db, label, workload, spec_id, run_uuid)
    report = get_workload_report(db, label, workload, spec_id, run_uuid)
    print_workload_report(report)
w.on_trait_change(show_report, 'value')
display(w)
show_report()
# Out:
# get_workload_report db=<sqlite3.Connection object at 0x7f85bf99a3d0> label=hmp workload=andebench spec_id=mp_option_default_b01 run_uuid=3251d69c-baad-423a-8ce0-2b058869ce78
# {   'label': u'hmp',
#     'name': u'andebench',
#     'primary': 'AndEMark Native',
#     'run_uuid': u'3251d69c-baad-423a-8ce0-2b058869ce78',
#     'runs': [   {   'AndEMark Java': u'1260',
#                     'AndEMark Native': u'9206',
#                     'cpu_energy': 108.45849999999999,
#                     'iteration': 1,
#                     'scpi_sensors BOARD_ENERGY_BIG': u'85.37006',
#                     'scpi_sensors BOARD_ENERGY_GPU': u'10.756525',
#                     'scpi_sensors BOARD_ENERGY_LITTLE': u'23.08844',
#                     'scpi_sensors BOARD_ENERGY_SYS': u'75.565603',
#                     'total_energy': 194.78062799999998},
#                 {   'AndEMark Java': u'1221',
#                     'AndEMark Native': u'8711',
#                     'cpu_energy': 112.807338,
#                     'iteration': 2,
#                     'scpi_sensors BOARD_ENERGY_BIG': u'88.485934',
#                     'scpi_sensors BOARD_ENERGY_GPU': u'11.639178',
#                     'scpi_sensors BOARD_ENERGY_LITTLE': u'24.321404',
#                     'scpi_sensors BOARD_ENERGY_SYS': u'79.871535',
#                     'total_energy': 204.318051},
#                 {   'AndEMark Java': u'1249',
#                     'AndEMark Native': u'8710',
#                     'cpu_energy': 112.45330899999999,
#                     'iteration': 3,
#                     'scpi_sensors BOARD_ENERGY_BIG': u'88.496282',
#                     'scpi_sensors BOARD_ENERGY_GPU': u'11.68627',
#                     'scpi_sensors BOARD_ENERGY_LITTLE': u'23.957027',
#                     'scpi_sensors BOARD_ENERGY_SYS': u'79.605895',
#                     'total_energy': 203.745474},
#                 {   'AndEMark Java': u'1238',
#                     'AndEMark Native': u'8712',
#                     'cpu_energy': 113.141196,
#                     'iteration': 4,
#                     'scpi_sensors BOARD_ENERGY_BIG': u'88.845053',
#                     'scpi_sensors BOARD_ENERGY_GPU': u'11.863973',
#                     'scpi_sensors BOARD_ENERGY_LITTLE': u'24.296143',
#                     'scpi_sensors BOARD_ENERGY_SYS': u'80.399073',
#                     'total_energy': 205.40424199999998},
#                 {   'AndEMark Java': u'1249',
#                     'AndEMark Native': u'8713',
#                     'cpu_energy': 113.39560200000001,
#                     'iteration': 5,
#                     'scpi_sensors BOARD_ENERGY_BIG': u'89.185775',
#                     'scpi_sensors BOARD_ENERGY_GPU': u'11.967397',
#                     'scpi_sensors BOARD_ENERGY_LITTLE': u'24.209827',
#                     'scpi_sensors BOARD_ENERGY_SYS': u'80.501694',
#                     'total_energy': 205.86469300000002}],
#     'spec_id': u'mp_option_default_b01',
#     'stats': {   'AndEMark Java': (   1243.4000000000001,
#                                       1243.3298091605157,
#                                       13.184839779079608),
#                  'AndEMark Native': (   8810.3999999999996,
#                                         8808.2279238199917,
#                                         197.80252778971251),
#                  'cpu_energy': (   112.05118899999999,
#                                    112.03611277698164,
#                                    1.8240853943793371),
#                  'scpi_sensors BOARD_ENERGY_BIG': (   88.076620800000001,
#                                                       88.065689252234307,
#                                                       1.3776672506778134),
#                  'scpi_sensors BOARD_ENERGY_GPU': (   11.5826686,
#                                                       11.574440667042726,
#                                                       0.42978783542980836),
#                  'scpi_sensors BOARD_ENERGY_LITTLE': (   23.9745682,
#                                                          23.970055251696667,
#                                                          0.46142886941906963),
#                  'scpi_sensors BOARD_ENERGY_SYS': (   79.188760000000002,
#                                                       79.166873642858562,
#                                                       1.8415267145400867),
#                  'total_energy': (   202.8226176,
#                                      202.78057456843189,
#                                      4.0909800536625829)}}

# %%
left = widgets.Dropdown(
    options=[],
    description='Left Workload'
)
right = widgets.Dropdown(
    options=[],
    description='Right Workload'
)

if conA:
    resultA=get_unique_combo_list_from_database(conA)
else:
    resultA=None
if conB:
    resultB=get_unique_combo_list_from_database(conB)
else:
    resultB=None

workloads=[]
if resultA:
    for res in resultA:
        if res[0] not in workloads:
            workloads.append(res[0])
if resultB:
    for res in resultB:
        if res[0] not in workloads:
            workloads.append(res[0])
        
selector = widgets.Dropdown(
    options=workloads,
    description='Select Workload:'
)
def on_selector_change():
    clear_output()
    spec_uuids=[]
    if resultA:
        for res in resultA:
            if res[0] == selector.value:
                spec_uuids.append(res[1]+', '+res[2]+', '+label_a)
    if resultB:
        for res in resultB:
            if res[0] == selector.value:
                spec_uuids.append(res[1]+', '+res[2]+', '+label_b)
    left.options=spec_uuids
    left.value=spec_uuids[0]
    left.value_selected=spec_uuids[0]
    right.options=spec_uuids
    right.value=spec_uuids[1]
    right.value_selected=spec_uuids[1]
    
selector.on_trait_change(on_selector_change, 'value')

button2 = widgets.Button(description="Show Results")
def on_button_clicked(b):
    clear_output()
    workload = selector.value
    spec_id1,run_uuid1, label=tuple([ x.strip() for x in left.value.split(",") if x.strip() ])
    db = conA
    if label == label_b:
        db = conB
    report1 = get_workload_report(db, label, workload, spec_id1, run_uuid1)
    spec_id2,run_uuid2, label=tuple([ x.strip() for x in right.value.split(",") if x.strip() ])
    db = conA
    if label == label_b:
        db = conB
    report2 = get_workload_report(db, label, workload, spec_id2, run_uuid2)
    compare_workload_reports(report1, report2, False)

button2.on_click(on_button_clicked)
display(selector)
on_selector_change()
display(left)
display(right)
display(button2)
# Out:
# Comparing workload reports for bbench_with_audio
#
# Reference is hmp mp_option_default_w01 3251d69c-baad-423a-8ce0-2b058869ce78
# Comparison is old mp_a57only_w01 cdce8e1d-880c-417b-a148-e72f32f5e0d4
#
# Primary metric for comparison is "execution_time"
# execution_time: mp_a57only_w01,'old' averaged lower (146.7513 vs 145.4267) overall
#                 This result is NOT LIKELY reliable (p=0.0758)
#
#
# execution_time                               mp_option_default_w01(hmp)      mp_a57only_w01(old)
# mean                                                         146.7513                 145.4267
# stdev                                                          1.0596                   1.1120
# This result is NOT LIKELY reliable (p=0.0758)
#
# Energy Comparison
#
# total_energy: mp_option_default_w01,'hmp' averaged less energy (161.0305J vs 167.2457J) overall
#               This result is LIKELY reliable (p=0.0090)
#
# cpu_energy: mp_option_default_w01,'hmp' averaged less energy (21.5425J vs 26.6172J) overall
#             This result is LIKELY reliable (p=0.0090)
#
# scpi_sensors BOARD_ENERGY_LITTLE(a53_cenr): mp_a57only_w01,'old' averaged less energy (13.0143J vs 1.8422J) overall
#                                             This result is LIKELY reliable (p=0.0090)
#
# scpi_sensors BOARD_ENERGY_BIG(a57_cenr): mp_option_default_w01,'hmp' averaged less energy (8.5282J vs 24.7750J) overall
#                                          This result is LIKELY reliable (p=0.0090)
#
#
# metric                                       mp_option_default_w01(hmp)      mp_a57only_w01(old)
# total_energy(mean)                                           161.0305                 167.2457
# total_energy(stdev)                                            1.1418                   3.5944
# cpu_energy(mean)                                              21.5425                  26.6172
# cpu_energy(stdev)                                              0.2214                   1.9849
# scpi_sensors BOARD_ENERGY_LITTLE(a53_cenr)(mean)                  13.0143                   1.8422
# scpi_sensors BOARD_ENERGY_LITTLE(a53_cenr)(stdev)                   0.2249                   0.2867
# scpi_sensors BOARD_ENERGY_BIG(a57_cenr)(mean)                   8.5282                  24.7750
# scpi_sensors BOARD_ENERGY_BIG(a57_cenr)(stdev)                   0.0488                   1.9784
#
#
# There are 5 other Interesting Scores:
# scpi_sensors BOARD_ENERGY_SYS(sys_cenr): mp_a57only_w01,'old' averaged less energy (119.5128J vs 118.0145J) overall
#                                          This result is LIKELY reliable (p=0.0090)
#
# scpi_sensors BOARD_ENERGY_GPU(gpu_cenr): mp_option_default_w01,'hmp' averaged less energy (19.9752J vs 22.6139J) overall
#                                          This result is LIKELY reliable (p=0.0090)
#
# scpi_sensors BOARD_ENERGY_BIG(a57_cenr): mp_option_default_w01,'hmp' averaged less energy (8.5282J vs 24.7750J) overall
#                                          This result is LIKELY reliable (p=0.0090)
#
# Mean Latency: mp_option_default_w01,'hmp' averaged lower (412.5780 vs 449.9380) overall
#               This result is LIKELY reliable (p=0.0090)
#
# scpi_sensors BOARD_ENERGY_LITTLE(a53_cenr): mp_a57only_w01,'old' averaged less energy (13.0143J vs 1.8422J) overall
#                                             This result is LIKELY reliable (p=0.0090)
#
#
# metric                                       mp_option_default_w01(hmp)      mp_a57only_w01(old)
# scpi_sensors BOARD_ENERGY_SYS(sys_cenr)(mean)                 119.5128                 118.0145
# scpi_sensors BOARD_ENERGY_SYS(sys_cenr)(stdev)                   0.8752                   1.4433
# scpi_sensors BOARD_ENERGY_GPU(gpu_cenr)(mean)                  19.9752                  22.6139
# scpi_sensors BOARD_ENERGY_GPU(gpu_cenr)(stdev)                   0.2141                   0.7522
# scpi_sensors BOARD_ENERGY_BIG(a57_cenr)(mean)                   8.5282                  24.7750
# scpi_sensors BOARD_ENERGY_BIG(a57_cenr)(stdev)                   0.0488                   1.9784
# Mean Latency(mean)                                           412.5780                 449.9380
# Mean Latency(stdev)                                            5.5635                  13.1272
# scpi_sensors BOARD_ENERGY_LITTLE(a53_cenr)(mean)                  13.0143                   1.8422
# scpi_sensors BOARD_ENERGY_LITTLE(a53_cenr)(stdev)                   0.2249                   0.2867

# %%
sideA='mp_a53bc'
sideB='mp_eas_nocgroups_interactive'

workloadsA=[]
workloadsB=[]

filtered_resultA=[]
for res in resultA:
    workload,spec_id,run_uuid=res
    if workload not in workloadsA:
        workloadsA.append(workload)
    if sideA in spec_id:
        filtered_resultA.append(res)

filtered_resultB=[]
for res in resultB:
    workload,spec_id,run_uuid=res
    if workload not in workloadsB and workload in workloadsA:
        workloadsB.append(workload)
    if sideB in spec_id:
        filtered_resultB.append(res)

common_workloads=[]
for workload in workloadsA:
    if workload in workloadsB:
        common_workloads.append(workload)
    
for workload in common_workloads:
    report1 = None
    report2 = None
    for work, spec_id,run_uuid in filtered_resultA:
        if work == workload:
            report1 = get_workload_report(conA, label_a, workload, spec_id, run_uuid)
            break
    if report1:
        for work, spec_id,run_uuid in filtered_resultB:
            if work == workload:
                report2 = get_workload_report(conB, label_b, workload, spec_id, run_uuid)
                break
    if report1 and report2:
        try:
            compare_workload_reports(report1, report2, False)
        except KeyError:
            print 'Error: KeyError raised for these reports: {}'.format(workload)
            pp.pprint(report1)
            pp.pprint(report2)
        print '\n\n'
# Out:
# Comparing workload reports for nenamark2
#
# Reference is hmp mp_a53bc_b11 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b11 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "nenamark score"
# nenamark score: mp_a53bc_b11,'hmp' averaged lower (59.6333 vs 59.7400) overall
#                 This result is NOT LIKELY reliable (p=0.4033)
#
#
# nenamark score                                      mp_a53bc_b11(hmp) mp_eas_nocgroups_interactive_b11(eas)
# mean                                                          59.6333                  59.7400
# stdev                                                          0.2261                   0.1200
# This result is NOT LIKELY reliable (p=0.4033)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b11,'eas' averaged less energy (306.0720J vs 205.3532J) overall
#               This result is LIKELY reliable (p=0.0027)
#
# cpu_energy: mp_eas_nocgroups_interactive_b11,'eas' averaged less energy (25.7688J vs 24.3261J) overall
#             This result is NOT LIKELY reliable (p=0.3861)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_a53bc_b11,'hmp' averaged less energy (20.2793J vs 20.3297J) overall
#                                This result is LIKELY reliable (p=0.0027)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b11,'eas' averaged less energy (5.4895J vs 3.9964J) overall
#                             This result is LIKELY reliable (p=0.0027)
#
#
# metric                                              mp_a53bc_b11(hmp) mp_eas_nocgroups_interactive_b11(eas)
# total_energy(mean)                                           306.0720                 205.3532
# total_energy(stdev)                                            2.8167                   2.7138
# cpu_energy(mean)                                              25.7688                  24.3261
# cpu_energy(stdev)                                              1.9149                   2.8145
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           20.2793                  20.3297
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.6587                   0.7048
# a57_cenr(BOARD_ENERGY_BIG)(mean)                               5.4895                   3.9964
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              1.6077                   2.1118
#
#
# There are 2 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_b11,'eas' averaged less energy (165.6204J vs 71.6217J) overall
#                             This result is LIKELY reliable (p=0.0027)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b11,'eas' averaged less energy (114.6827J vs 109.4055J) overall
#                             This result is LIKELY reliable (p=0.0027)
#
#
# metric                                              mp_a53bc_b11(hmp) mp_eas_nocgroups_interactive_b11(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                             165.6204                  71.6217
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.6440                   0.1256
# sys_cenr(BOARD_ENERGY_SYS)(mean)                             114.6827                 109.4055
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              0.5844                   0.1645
#
#
#
# Comparing workload reports for egypt_2.5.1_HD_off
#
# Reference is hmp mp_a53bc_b12 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b12 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "FPS_0"
# FPS_0: mp_a53bc_b12,'hmp' averaged lower (133.0000 vs 134.4000) overall
#        This result is LIKELY reliable (p=0.0002)
#
#
# FPS_0                                               mp_a53bc_b12(hmp) mp_eas_nocgroups_interactive_b12(eas)
# mean                                                         133.0000                 134.4000
# stdev                                                          0.0000                   0.4899
# This result is LIKELY reliable (p=0.0002)
#
# Energy Comparison
#
# total_energy: mp_a53bc_b12,'hmp' averaged less energy (418.4306J vs 433.9943J) overall
#               This result is LIKELY reliable (p=0.0022)
#
# cpu_energy: mp_a53bc_b12,'hmp' averaged less energy (67.3658J vs 72.5873J) overall
#             This result is LIKELY reliable (p=0.0022)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_a53bc_b12,'hmp' averaged less energy (12.9538J vs 16.9833J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_a53bc_b12,'hmp' averaged less energy (54.4119J vs 55.6040J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b12(hmp) mp_eas_nocgroups_interactive_b12(eas)
# total_energy(mean)                                           418.4306                 433.9943
# total_energy(stdev)                                            5.4146                   4.0297
# cpu_energy(mean)                                              67.3658                  72.5873
# cpu_energy(stdev)                                              0.5707                   1.1475
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           12.9538                  16.9833
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.2793                   0.2406
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              54.4119                  55.6040
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.3858                   1.3032
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b12,'hmp' averaged less energy (219.9870J vs 225.4396J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Frames_0: mp_a53bc_b12,'hmp' averaged lower (15006.8000 vs 15186.2000) overall
#           This result is LIKELY reliable (p=0.0022)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_a53bc_b12,'hmp' averaged less energy (131.0778J vs 135.9674J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b12(hmp) mp_eas_nocgroups_interactive_b12(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                             219.9870                 225.4396
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.7432                   0.7564
# Frames_0(mean)                                             15006.8000               15186.2000
# Frames_0(stdev)                                               13.2045                  29.0200
# sys_cenr(BOARD_ENERGY_SYS)(mean)                             131.0778                 135.9674
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              4.3535                   3.0668
#
#
#
# Comparing workload reports for egypt_2.5.1_HD_on
#
# Reference is hmp mp_a53bc_b13 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b13 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "FPS_0"
# FPS_0: mp_a53bc_b13,'hmp' averaged lower (59.0000 vs 60.0000) overall
#        This result is LIKELY reliable (p=0.0002)
#
#
# FPS_0                                               mp_a53bc_b13(hmp) mp_eas_nocgroups_interactive_b13(eas)
# mean                                                          59.0000                  60.0000
# stdev                                                          0.0000                   0.0000
# This result is LIKELY reliable (p=0.0002)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b13,'eas' averaged less energy (287.2548J vs 215.9112J) overall
#               This result is LIKELY reliable (p=0.0022)
#
# cpu_energy: mp_eas_nocgroups_interactive_b13,'eas' averaged less energy (36.4829J vs 34.9254J) overall
#             This result is LIKELY reliable (p=0.0022)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_a53bc_b13,'hmp' averaged less energy (18.9697J vs 25.1599J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b13,'eas' averaged less energy (17.5132J vs 9.7655J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b13(hmp) mp_eas_nocgroups_interactive_b13(eas)
# total_energy(mean)                                           287.2548                 215.9112
# total_energy(stdev)                                            4.2386                   6.2839
# cpu_energy(mean)                                              36.4829                  34.9254
# cpu_energy(stdev)                                              0.5480                   0.4384
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           18.9697                  25.1599
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.2637                   0.3322
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              17.5132                   9.7655
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.5264                   0.5349
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_b13,'eas' averaged less energy (121.2901J vs 57.0672J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Frames_0: mp_a53bc_b13,'hmp' averaged lower (6631.0000 vs 6762.4000) overall
#           This result is LIKELY reliable (p=0.0022)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b13,'eas' averaged less energy (129.4819J vs 123.9186J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b13(hmp) mp_eas_nocgroups_interactive_b13(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                             121.2901                  57.0672
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.6930                   0.7001
# Frames_0(mean)                                              6631.0000                6762.4000
# Frames_0(stdev)                                               14.8257                   5.3889
# sys_cenr(BOARD_ENERGY_SYS)(mean)                             129.4819                 123.9186
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              3.8660                   5.1493
#
#
#
# Comparing workload reports for t-rex_2.7.0_HD_off
#
# Reference is hmp mp_a53bc_b14 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b14 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "FPS_0"
# FPS_0: mp_a53bc_b14,'hmp' averaged lower (23.0000 vs 23.2000) overall
#        This result is NOT LIKELY reliable (p=0.1573)
#
#
# FPS_0                                               mp_a53bc_b14(hmp) mp_eas_nocgroups_interactive_b14(eas)
# mean                                                          23.0000                  23.2000
# stdev                                                          0.0000                   0.4000
# This result is NOT LIKELY reliable (p=0.1573)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b14,'eas' averaged less energy (203.1914J vs 201.7132J) overall
#               This result is NOT LIKELY reliable (p=0.3272)
#
# cpu_energy: mp_eas_nocgroups_interactive_b14,'eas' averaged less energy (23.3414J vs 19.3994J) overall
#             This result is NOT LIKELY reliable (p=0.0500)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b14,'eas' averaged less energy (11.2946J vs 11.2305J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b14,'eas' averaged less energy (12.0468J vs 8.1690J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b14(hmp) mp_eas_nocgroups_interactive_b14(eas)
# total_energy(mean)                                           203.1914                 201.7132
# total_energy(stdev)                                            1.5257                   2.2510
# cpu_energy(mean)                                              23.3414                  19.3994
# cpu_energy(stdev)                                              1.0761                   2.5639
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           11.2946                  11.2305
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.2989                   0.4915
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              12.0468                   8.1690
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.8203                   2.0995
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b14,'hmp' averaged less energy (108.5077J vs 110.2721J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Frames_0: mp_a53bc_b14,'hmp' averaged lower (1294.5000 vs 1310.8000) overall
#           This result is LIKELY reliable (p=0.0021)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_a53bc_b14,'hmp' averaged less energy (71.3422J vs 72.0416J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b14(hmp) mp_eas_nocgroups_interactive_b14(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                             108.5077                 110.2721
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.2864                   0.3936
# Frames_0(mean)                                              1294.5000                1310.8000
# Frames_0(stdev)                                                1.9621                   4.9558
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              71.3422                  72.0416
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              0.9249                   1.7369
#
#
#
# Comparing workload reports for t-rex_2.7.0_HD_on
#
# Reference is hmp mp_a53bc_b15 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b15 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "FPS_0"
# FPS_0: mp_a53bc_b15,'hmp' averaged lower (21.4000 vs 39.4000) overall
#        This result is LIKELY reliable (p=0.0013)
#
#
# FPS_0                                               mp_a53bc_b15(hmp) mp_eas_nocgroups_interactive_b15(eas)
# mean                                                          21.4000                  39.4000
# stdev                                                          0.4899                   0.4899
# This result is LIKELY reliable (p=0.0013)
#
# Energy Comparison
#
# total_energy: mp_a53bc_b15,'hmp' averaged less energy (201.1280J vs 235.7130J) overall
#               This result is NOT LIKELY reliable (p=0.8065)
#
# cpu_energy: mp_a53bc_b15,'hmp' averaged less energy (24.0917J vs 27.3332J) overall
#             This result is NOT LIKELY reliable (p=0.7133)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_a53bc_b15,'hmp' averaged less energy (12.3721J vs 18.4402J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b15,'eas' averaged less energy (11.7195J vs 8.8930J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b15(hmp) mp_eas_nocgroups_interactive_b15(eas)
# total_energy(mean)                                           201.1280                 235.7130
# total_energy(stdev)                                            4.3332                  73.0312
# cpu_energy(mean)                                              24.0917                  27.3332
# cpu_energy(stdev)                                              3.1296                   7.7891
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           12.3721                  18.4402
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.6996                   3.9791
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              11.7195                   8.8930
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              2.4764                   3.8245
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b15,'hmp' averaged less energy (104.8797J vs 119.2179J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Frames_0: mp_a53bc_b15,'hmp' averaged lower (1203.3000 vs 2205.8000) overall
#           This result is LIKELY reliable (p=0.0021)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_a53bc_b15,'hmp' averaged less energy (72.1566J vs 89.1618J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b15(hmp) mp_eas_nocgroups_interactive_b15(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                             104.8797                 119.2179
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.5126                  43.0217
# Frames_0(mean)                                              1203.3000                2205.8000
# Frames_0(stdev)                                                1.7349                   8.3762
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              72.1566                  89.1618
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              1.7483                  22.3060
#
#
#
# Error: KeyError raised for these reports: manhattan_on
# {   'label': 'hmp',
#     'name': u'manhattan_on',
#     'primary': 'FPS_0',
#     'run_uuid': u'37ba5db4-c06c-484b-90db-cecad1017820',
#     'runs': [],
#     'spec_id': u'mp_a53bc_b16',
#     'stats': {   }}
# {   'label': 'eas',
#     'name': u'manhattan_on',
#     'primary': 'FPS_0',
#     'run_uuid': u'bc4a8556-fe81-4d2f-994b-c402c3d6ffd2',
#     'runs': [],
#     'spec_id': u'mp_eas_nocgroups_interactive_b16',
#     'stats': {   }}
#
#
#
# Error: KeyError raised for these reports: manhattan_off
# {   'label': 'hmp',
#     'name': u'manhattan_off',
#     'primary': 'FPS_0',
#     'run_uuid': u'37ba5db4-c06c-484b-90db-cecad1017820',
#     'runs': [],
#     'spec_id': u'mp_a53bc_b17',
#     'stats': {   }}
# {   'label': 'eas',
#     'name': u'manhattan_off',
#     'primary': 'FPS_0',
#     'run_uuid': u'bc4a8556-fe81-4d2f-994b-c402c3d6ffd2',
#     'runs': [],
#     'spec_id': u'mp_eas_nocgroups_interactive_b17',
#     'stats': {   }}
#
#
#
# Comparing workload reports for andebench
#
# Reference is hmp mp_a53bc_b01 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b01 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "AndEMark Native"
# AndEMark Native: mp_a53bc_b01,'hmp' averaged lower (8701.2222 vs 8716.2000) overall
#                  This result is NOT LIKELY reliable (p=0.0712)
#
#
# AndEMark Native                                     mp_a53bc_b01(hmp) mp_eas_nocgroups_interactive_b01(eas)
# mean                                                        8701.2222                8716.2000
# stdev                                                         11.9515                  12.4161
# This result is NOT LIKELY reliable (p=0.0712)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b01,'eas' averaged less energy (209.3939J vs 199.9294J) overall
#               This result is LIKELY reliable (p=0.0136)
#
# cpu_energy: mp_eas_nocgroups_interactive_b01,'eas' averaged less energy (118.0652J vs 110.1746J) overall
#             This result is LIKELY reliable (p=0.0063)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b01,'eas' averaged less energy (26.0248J vs 25.8323J) overall
#                                This result is LIKELY reliable (p=0.0027)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b01,'eas' averaged less energy (92.0404J vs 84.3423J) overall
#                             This result is LIKELY reliable (p=0.0027)
#
#
# metric                                              mp_a53bc_b01(hmp) mp_eas_nocgroups_interactive_b01(eas)
# total_energy(mean)                                           209.3939                 199.9294
# total_energy(stdev)                                            3.9099                   4.8641
# cpu_energy(mean)                                             118.0652                 110.1746
# cpu_energy(stdev)                                              2.4853                   3.8065
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           26.0248                  25.8323
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.5428                   0.8539
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              92.0404                  84.3423
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              1.9749                   3.0038
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b01,'hmp' averaged less energy (11.3070J vs 11.6230J) overall
#                             This result is LIKELY reliable (p=0.0027)
#
# AndEMark Java: mp_a53bc_b01,'hmp' averaged lower (1263.4444 vs 1276.8000) overall
#                This result is NOT LIKELY reliable (p=0.5930)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b01,'eas' averaged less energy (80.0217J vs 78.1317J) overall
#                             This result is LIKELY reliable (p=0.0027)
#
#
# metric                                              mp_a53bc_b01(hmp) mp_eas_nocgroups_interactive_b01(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                              11.3070                  11.6230
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.2565                   0.0771
# AndEMark Java(mean)                                         1263.4444                1276.8000
# AndEMark Java(stdev)                                           8.8583                  26.6563
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              80.0217                  78.1317
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              1.2272                   1.0301
#
#
#
# Comparing workload reports for andebenchst
#
# Reference is hmp mp_a53bc_b02 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b02 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "AndEMark Native"
# AndEMark Native: mp_eas_nocgroups_interactive_b02,'eas' averaged lower (3071.0000 vs 3068.6000) overall
#                  This result is NOT LIKELY reliable (p=0.2639)
#
#
# AndEMark Native                                     mp_a53bc_b02(hmp) mp_eas_nocgroups_interactive_b02(eas)
# mean                                                        3071.0000                3068.6000
# stdev                                                          6.6783                   2.3324
# This result is NOT LIKELY reliable (p=0.2639)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b02,'eas' averaged less energy (97.0099J vs 92.0488J) overall
#               This result is NOT LIKELY reliable (p=0.0662)
#
# cpu_energy: mp_eas_nocgroups_interactive_b02,'eas' averaged less energy (37.8747J vs 32.9340J) overall
#             This result is NOT LIKELY reliable (p=0.0662)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b02,'eas' averaged less energy (4.5157J vs 2.8830J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b02,'eas' averaged less energy (33.3590J vs 30.0511J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b02(hmp) mp_eas_nocgroups_interactive_b02(eas)
# total_energy(mean)                                            97.0099                  92.0488
# total_energy(stdev)                                            0.9924                   3.6703
# cpu_energy(mean)                                              37.8747                  32.9340
# cpu_energy(stdev)                                              0.5526                   3.4489
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            4.5157                   2.8830
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.1082                   1.0334
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              33.3590                  30.0511
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.4969                   2.4201
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b02,'hmp' averaged less energy (7.3072J vs 7.3497J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# AndEMark Java: mp_eas_nocgroups_interactive_b02,'eas' averaged lower (548.3000 vs 528.6000) overall
#                This result is LIKELY reliable (p=0.0026)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b02,'eas' averaged less energy (51.8280J vs 51.7651J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b02(hmp) mp_eas_nocgroups_interactive_b02(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                               7.3072                   7.3497
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.1163                   0.1741
# AndEMark Java(mean)                                          548.3000                 528.6000
# AndEMark Java(stdev)                                           7.6164                   3.4409
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              51.8280                  51.7651
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              0.4784                   1.0604
#
#
#
# Comparing workload reports for caffeinemark
#
# Reference is hmp mp_a53bc_b04 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b04 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "OverallScore"
# OverallScore: mp_a53bc_b04,'hmp' averaged lower (46431.1000 vs 47418.0000) overall
#               This result is LIKELY reliable (p=0.0022)
#
#
# OverallScore                                        mp_a53bc_b04(hmp) mp_eas_nocgroups_interactive_b04(eas)
# mean                                                       46431.1000               47418.0000
# stdev                                                        367.5047                 428.2079
# This result is LIKELY reliable (p=0.0022)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b04,'eas' averaged less energy (140.9522J vs 137.7553J) overall
#               This result is NOT LIKELY reliable (p=0.0662)
#
# cpu_energy: mp_eas_nocgroups_interactive_b04,'eas' averaged less energy (84.9714J vs 81.9783J) overall
#             This result is NOT LIKELY reliable (p=0.0662)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b04,'eas' averaged less energy (8.0962J vs 5.8318J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b04,'eas' averaged less energy (76.8752J vs 76.1466J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b04(hmp) mp_eas_nocgroups_interactive_b04(eas)
# total_energy(mean)                                           140.9522                 137.7553
# total_energy(stdev)                                            1.1992                   3.3818
# cpu_energy(mean)                                              84.9714                  81.9783
# cpu_energy(stdev)                                              0.8747                   2.7941
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            8.0962                   5.8318
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.3996                   2.1210
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              76.8752                  76.1466
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.6714                   0.7382
#
#
# There are 8 other Interesting Scores:
# String: mp_a53bc_b04,'hmp' averaged lower (20899.1000 vs 23548.8000) overall
#         This result is LIKELY reliable (p=0.0022)
#
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b04,'hmp' averaged less energy (6.7141J vs 7.2275J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Float: mp_a53bc_b04,'hmp' averaged lower (44092.4000 vs 44639.8000) overall
#        This result is NOT LIKELY reliable (p=0.0662)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b04,'eas' averaged less energy (49.2667J vs 48.5495J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Logic: mp_eas_nocgroups_interactive_b04,'eas' averaged lower (91057.3000 vs 90985.8000) overall
#        This result is NOT LIKELY reliable (p=0.0662)
#
# Sieve: mp_a53bc_b04,'hmp' averaged lower (55542.5000 vs 55854.6000) overall
#        This result is LIKELY reliable (p=0.0275)
#
# Method: mp_eas_nocgroups_interactive_b04,'eas' averaged lower (30107.0000 vs 29803.6000) overall
#         This result is NOT LIKELY reliable (p=0.7133)
#
# Loop: mp_eas_nocgroups_interactive_b04,'eas' averaged lower (71484.3000 vs 71454.4000) overall
#       This result is NOT LIKELY reliable (p=0.5403)
#
#
# metric                                              mp_a53bc_b04(hmp) mp_eas_nocgroups_interactive_b04(eas)
# String(mean)                                               20899.1000               23548.8000
# String(stdev)                                                747.8609                 823.8251
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                               6.7141                   7.2275
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.0900                   0.0398
# Float(mean)                                                44092.4000               44639.8000
# Float(stdev)                                                 564.5418                  43.5725
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              49.2667                  48.5495
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              0.2784                   0.5866
# Logic(mean)                                                91057.3000               90985.8000
# Logic(stdev)                                                 144.3468                  48.2552
# Sieve(mean)                                                55542.5000               55854.6000
# Sieve(stdev)                                                 259.7011                 160.2331
# Method(mean)                                               30107.0000               29803.6000
# Method(stdev)                                                878.0109                 837.8765
# Loop(mean)                                                 71484.3000               71454.4000
# Loop(stdev)                                                  286.6189                 298.5261
#
#
#
# Comparing workload reports for cfbench
#
# Reference is hmp mp_a53bc_b05 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b05 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "overall_score"
# overall_score: mp_eas_nocgroups_interactive_b05,'eas' averaged lower (32245.2000 vs 31830.8000) overall
#                This result is NOT LIKELY reliable (p=0.0662)
#
#
# overall_score                                       mp_a53bc_b05(hmp) mp_eas_nocgroups_interactive_b05(eas)
# mean                                                       32245.2000               31830.8000
# stdev                                                        265.5236                 389.9484
# This result is NOT LIKELY reliable (p=0.0662)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b05,'eas' averaged less energy (421.5088J vs 394.9180J) overall
#               This result is LIKELY reliable (p=0.0022)
#
# cpu_energy: mp_eas_nocgroups_interactive_b05,'eas' averaged less energy (226.4326J vs 223.3728J) overall
#             This result is LIKELY reliable (p=0.0275)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b05,'eas' averaged less energy (68.3293J vs 68.0179J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b05,'eas' averaged less energy (158.1033J vs 155.3549J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b05(hmp) mp_eas_nocgroups_interactive_b05(eas)
# total_energy(mean)                                           421.5088                 394.9180
# total_energy(stdev)                                            3.3843                   2.7577
# cpu_energy(mean)                                             226.4326                 223.3728
# cpu_energy(stdev)                                              1.7367                   2.3083
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           68.3293                  68.0179
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.4663                   0.5021
# a57_cenr(BOARD_ENERGY_BIG)(mean)                             158.1033                 155.3549
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              1.7246                   2.5097
#
#
# There are 4 other Interesting Scores:
# java_score: mp_eas_nocgroups_interactive_b05,'eas' averaged lower (26941.5000 vs 26200.2000) overall
#             This result is LIKELY reliable (p=0.0071)
#
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_b05,'eas' averaged less energy (57.0353J vs 36.2518J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b05,'eas' averaged less energy (138.0409J vs 135.2933J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# native_score: mp_a53bc_b05,'hmp' averaged lower (40201.8000 vs 40277.4000) overall
#               This result is NOT LIKELY reliable (p=0.3913)
#
#
# metric                                              mp_a53bc_b05(hmp) mp_eas_nocgroups_interactive_b05(eas)
# java_score(mean)                                           26941.5000               26200.2000
# java_score(stdev)                                            222.3094                 401.8415
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                              57.0353                  36.2518
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.8940                   0.1419
# sys_cenr(BOARD_ENERGY_SYS)(mean)                             138.0409                 135.2933
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              2.0563                   0.6064
# native_score(mean)                                         40201.8000               40277.4000
# native_score(stdev)                                          363.7867                 397.5206
#
#
#
# Comparing workload reports for linpack
#
# Reference is hmp mp_a53bc_b07 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b07 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "Linpack MT"
# Linpack MT: mp_eas_nocgroups_interactive_b07,'eas' averaged lower (429.7534 vs 366.0560) overall
#             This result is NOT LIKELY reliable (p=0.0500)
#
#
# Linpack MT                                          mp_a53bc_b07(hmp) mp_eas_nocgroups_interactive_b07(eas)
# mean                                                         429.7534                 366.0560
# stdev                                                         40.9058                  51.9640
# This result is NOT LIKELY reliable (p=0.0500)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b07,'eas' averaged less energy (16.0448J vs 13.0663J) overall
#               This result is LIKELY reliable (p=0.0275)
#
# cpu_energy: mp_eas_nocgroups_interactive_b07,'eas' averaged less energy (5.0758J vs 3.4033J) overall
#             This result is NOT LIKELY reliable (p=0.1113)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b07,'eas' averaged less energy (1.4543J vs 0.6523J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b07,'eas' averaged less energy (3.6215J vs 2.7510J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b07(hmp) mp_eas_nocgroups_interactive_b07(eas)
# total_energy(mean)                                            16.0448                  13.0663
# total_energy(stdev)                                            1.7154                   1.6268
# cpu_energy(mean)                                               5.0758                   3.4033
# cpu_energy(stdev)                                              0.9143                   1.7294
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            1.4543                   0.6523
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.1341                   0.3914
# a57_cenr(BOARD_ENERGY_BIG)(mean)                               3.6215                   2.7510
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.8162                   1.3767
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_b07,'hmp' averaged less energy (1.1170J vs 1.1512J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Linpack ST: mp_a53bc_b07,'hmp' averaged lower (176.3298 vs 199.0154) overall
#             This result is NOT LIKELY reliable (p=0.7133)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b07,'eas' averaged less energy (9.8521J vs 8.5119J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b07(hmp) mp_eas_nocgroups_interactive_b07(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                               1.1170                   1.1512
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.1136                   0.0350
# Linpack ST(mean)                                             176.3298                 199.0154
# Linpack ST(stdev)                                             33.2281                  46.9288
# sys_cenr(BOARD_ENERGY_SYS)(mean)                               9.8521                   8.5119
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              1.0290                   0.1499
#
#
#
# Comparing workload reports for quadrant
#
# Reference is hmp mp_a53bc_b08 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b08 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "benchmark_score"
# benchmark_score: mp_eas_nocgroups_interactive_b08,'eas' averaged lower (12187.6000 vs 11708.2000) overall
#                  This result is LIKELY reliable (p=0.0275)
#
#
# benchmark_score                                     mp_a53bc_b08(hmp) mp_eas_nocgroups_interactive_b08(eas)
# mean                                                       12187.6000               11708.2000
# stdev                                                        385.8270                 207.0308
# This result is LIKELY reliable (p=0.0275)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b08,'eas' averaged less energy (106.4811J vs 93.7859J) overall
#               This result is NOT LIKELY reliable (p=0.0662)
#
# cpu_energy: mp_eas_nocgroups_interactive_b08,'eas' averaged less energy (35.3244J vs 30.2952J) overall
#             This result is NOT LIKELY reliable (p=0.0662)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b08,'eas' averaged less energy (6.9833J vs 6.9664J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b08,'eas' averaged less energy (28.3410J vs 23.3288J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b08(hmp) mp_eas_nocgroups_interactive_b08(eas)
# total_energy(mean)                                           106.4811                  93.7859
# total_energy(stdev)                                            3.6473                   9.0481
# cpu_energy(mean)                                              35.3244                  30.2952
# cpu_energy(stdev)                                              0.8940                   4.1392
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            6.9833                   6.9664
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.2849                   0.8417
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              28.3410                  23.3288
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.6473                   3.3318
#
#
# There are 7 other Interesting Scores:
# benchmark_cpu_score: mp_eas_nocgroups_interactive_b08,'eas' averaged lower (47198.0000 vs 44673.8000) overall
#                      This result is LIKELY reliable (p=0.0275)
#
# benchmark_g2d_score: mp_a53bc_b08,'hmp' averaged lower (487.7000 vs 695.2000) overall
#                      This result is NOT LIKELY reliable (p=0.3874)
#
# benchmark_memory_score: mp_a53bc_b08,'hmp' averaged lower (8859.9000 vs 9050.8000) overall
#                         This result is LIKELY reliable (p=0.0185)
#
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_b08,'eas' averaged less energy (17.1740J vs 12.0023J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# benchmark_io_score: mp_eas_nocgroups_interactive_b08,'eas' averaged lower (2290.7000 vs 1973.4000) overall
#                     This result is LIKELY reliable (p=0.0022)
#
# benchmark_g3d_score: mp_a53bc_b08,'hmp' averaged lower (2101.6000 vs 2148.0000) overall
#                      This result is LIKELY reliable (p=0.0039)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b08,'eas' averaged less energy (53.9828J vs 51.4885J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b08(hmp) mp_eas_nocgroups_interactive_b08(eas)
# benchmark_cpu_score(mean)                                  47198.0000               44673.8000
# benchmark_cpu_score(stdev)                                  1914.5008                1219.5767
# benchmark_g2d_score(mean)                                    487.7000                 695.2000
# benchmark_g2d_score(stdev)                                    37.2345                 244.8309
# benchmark_memory_score(mean)                                8859.9000                9050.8000
# benchmark_memory_score(stdev)                                116.0831                  99.8086
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                              17.1740                  12.0023
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.2881                   0.5435
# benchmark_io_score(mean)                                    2290.7000                1973.4000
# benchmark_io_score(stdev)                                     79.5588                 199.0845
# benchmark_g3d_score(mean)                                   2101.6000                2148.0000
# benchmark_g3d_score(stdev)                                    48.9718                   8.1240
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              53.9828                  51.4885
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              2.6531                   4.3912
#
#
#
# Comparing workload reports for smartbench
#
# Reference is hmp mp_a53bc_b09 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b09 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "Smartbench: valueGame"
# Smartbench: valueGame: mp_a53bc_b09,'hmp' averaged lower (3795.0000 vs 4535.2000) overall
#                        This result is LIKELY reliable (p=0.0022)
#
#
# Smartbench: valueGame                               mp_a53bc_b09(hmp) mp_eas_nocgroups_interactive_b09(eas)
# mean                                                        3795.0000                4535.2000
# stdev                                                         15.7734                  12.6712
# This result is LIKELY reliable (p=0.0022)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b09,'eas' averaged less energy (116.7565J vs 93.4458J) overall
#               This result is LIKELY reliable (p=0.0022)
#
# cpu_energy: mp_eas_nocgroups_interactive_b09,'eas' averaged less energy (34.1024J vs 28.7604J) overall
#             This result is LIKELY reliable (p=0.0200)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b09,'eas' averaged less energy (10.9158J vs 10.0961J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b09,'eas' averaged less energy (23.1866J vs 18.6642J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b09(hmp) mp_eas_nocgroups_interactive_b09(eas)
# total_energy(mean)                                           116.7565                  93.4458
# total_energy(stdev)                                            1.1287                   3.2456
# cpu_energy(mean)                                              34.1024                  28.7604
# cpu_energy(stdev)                                              0.8260                   2.9055
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           10.9158                  10.0961
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.1597                   0.9806
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              23.1866                  18.6642
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.8407                   1.9286
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_b09,'eas' averaged less energy (28.0625J vs 15.4466J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Smartbench: valueProd: mp_a53bc_b09,'hmp' averaged lower (7238.4000 vs 7415.4000) overall
#                        This result is NOT LIKELY reliable (p=0.3272)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b09,'eas' averaged less energy (54.5916J vs 49.2388J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b09(hmp) mp_eas_nocgroups_interactive_b09(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                              28.0625                  15.4466
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.2469                   0.1654
# Smartbench: valueProd(mean)                                 7238.4000                7415.4000
# Smartbench: valueProd(stdev)                                 188.2951                 309.4916
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              54.5916                  49.2388
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              0.3459                   0.7484
#
#
#
# Comparing workload reports for sqlitebm
#
# Reference is hmp mp_a53bc_b10 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_b10 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "execution_time"
# execution_time: mp_eas_nocgroups_interactive_b10,'eas' averaged lower (62.0433 vs 56.3049) overall
#                 This result is NOT LIKELY reliable (p=0.1113)
#
#
# execution_time                                      mp_a53bc_b10(hmp) mp_eas_nocgroups_interactive_b10(eas)
# mean                                                          62.0433                  56.3049
# stdev                                                          4.5779                   6.2359
# This result is NOT LIKELY reliable (p=0.1113)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_b10,'eas' averaged less energy (80.2999J vs 66.9595J) overall
#               This result is NOT LIKELY reliable (p=0.0500)
#
# cpu_energy: mp_eas_nocgroups_interactive_b10,'eas' averaged less energy (20.1442J vs 13.3249J) overall
#             This result is LIKELY reliable (p=0.0373)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_b10,'eas' averaged less energy (5.9560J vs 5.6011J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_b10,'eas' averaged less energy (14.1882J vs 7.7238J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b10(hmp) mp_eas_nocgroups_interactive_b10(eas)
# total_energy(mean)                                            80.2999                  66.9595
# total_energy(stdev)                                            5.1384                   9.7940
# cpu_energy(mean)                                              20.1442                  13.3249
# cpu_energy(stdev)                                              0.9238                   3.7834
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            5.9560                   5.6011
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.3337                   1.4788
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              14.1882                   7.7238
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.6407                   2.3139
#
#
# There are 2 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_b10,'eas' averaged less energy (7.8557J vs 6.9504J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_b10,'eas' averaged less energy (52.3000J vs 46.6841J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_b10(hmp) mp_eas_nocgroups_interactive_b10(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                               7.8557                   6.9504
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.5147                   0.7877
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              52.3000                  46.6841
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              3.7929                   5.3606
#
#
#
# Comparing workload reports for bbench_with_audio
#
# Reference is hmp mp_a53bc_w01 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_w01 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "execution_time"
# execution_time: mp_a53bc_w01,'hmp' averaged lower (146.7402 vs 148.8988) overall
#                 This result is LIKELY reliable (p=0.0373)
#
#
# execution_time                                      mp_a53bc_w01(hmp) mp_eas_nocgroups_interactive_w01(eas)
# mean                                                         146.7402                 148.8988
# stdev                                                          1.2572                   1.2993
# This result is LIKELY reliable (p=0.0373)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_w01,'eas' averaged less energy (165.7243J vs 160.8855J) overall
#               This result is LIKELY reliable (p=0.0200)
#
# cpu_energy: mp_eas_nocgroups_interactive_w01,'eas' averaged less energy (23.0173J vs 22.3076J) overall
#             This result is NOT LIKELY reliable (p=0.0662)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_a53bc_w01,'hmp' averaged less energy (12.6133J vs 14.4185J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_w01,'eas' averaged less energy (10.4040J vs 7.8891J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_w01(hmp) mp_eas_nocgroups_interactive_w01(eas)
# total_energy(mean)                                           165.7243                 160.8855
# total_energy(stdev)                                            1.2039                   2.9422
# cpu_energy(mean)                                              23.0173                  22.3076
# cpu_energy(stdev)                                              0.4210                   2.0702
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                           12.6133                  14.4185
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.2688                   0.9785
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              10.4040                   7.8891
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.4701                   1.1092
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_w01,'eas' averaged less energy (22.7652J vs 18.8430J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# Mean Latency: mp_a53bc_w01,'hmp' averaged lower (422.2680 vs 500.0100) overall
#               This result is LIKELY reliable (p=0.0022)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_w01,'eas' averaged less energy (119.9418J vs 119.7349J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_w01(hmp) mp_eas_nocgroups_interactive_w01(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                              22.7652                  18.8430
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.2667                   0.1431
# Mean Latency(mean)                                           422.2680                 500.0100
# Mean Latency(stdev)                                            4.2744                  16.8586
# sys_cenr(BOARD_ENERGY_SYS)(mean)                             119.9418                 119.7349
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              1.0434                   1.1217
#
#
#
# Comparing workload reports for audio
#
# Reference is hmp mp_a53bc_w02 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_w02 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "execution_time"
# execution_time: mp_a53bc_w02,'hmp' averaged lower (30.0261 vs 30.0303) overall
#                 This result is LIKELY reliable (p=0.0101)
#
#
# execution_time                                      mp_a53bc_w02(hmp) mp_eas_nocgroups_interactive_w02(eas)
# mean                                                          30.0261                  30.0303
# stdev                                                          0.0057                   0.0000
# This result is LIKELY reliable (p=0.0101)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_w02,'eas' averaged less energy (34.4396J vs 28.7487J) overall
#               This result is LIKELY reliable (p=0.0033)
#
# cpu_energy: mp_eas_nocgroups_interactive_w02,'eas' averaged less energy (6.7898J vs 2.2026J) overall
#             This result is LIKELY reliable (p=0.0071)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_w02,'eas' averaged less energy (2.1890J vs 1.0705J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_w02,'eas' averaged less energy (4.6009J vs 1.1321J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_w02(hmp) mp_eas_nocgroups_interactive_w02(eas)
# total_energy(mean)                                            34.4396                  28.7487
# total_energy(stdev)                                            2.0975                   1.4182
# cpu_energy(mean)                                               6.7898                   2.2026
# cpu_energy(stdev)                                              1.8956                   1.2954
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            2.1890                   1.0705
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.7044                   0.1323
# a57_cenr(BOARD_ENERGY_BIG)(mean)                               4.6009                   1.1321
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              1.2148                   1.1639
#
#
# There are 2 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_a53bc_w02,'hmp' averaged less energy (2.7718J vs 2.9325J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_w02,'eas' averaged less energy (24.8779J vs 23.6136J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_w02(hmp) mp_eas_nocgroups_interactive_w02(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                               2.7718                   2.9325
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.1463                   0.0621
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              24.8779                  23.6136
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              0.2100                   0.0816
#
#
#
# Comparing workload reports for browserlaunchx8
#
# Reference is hmp mp_a53bc_w03 37ba5db4-c06c-484b-90db-cecad1017820
# Comparison is eas mp_eas_nocgroups_interactive_w03 bc4a8556-fe81-4d2f-994b-c402c3d6ffd2
#
# Primary metric for comparison is "time"
# time: mp_eas_nocgroups_interactive_w03,'eas' averaged lower (0.5165 vs 0.4697) overall
#       This result is LIKELY reliable (p=0.0101)
#
#
# time                                                mp_a53bc_w03(hmp) mp_eas_nocgroups_interactive_w03(eas)
# mean                                                           0.5165                   0.4697
# stdev                                                          0.0166                   0.0193
# This result is LIKELY reliable (p=0.0101)
#
# Energy Comparison
#
# total_energy: mp_eas_nocgroups_interactive_w03,'eas' averaged less energy (82.7837J vs 70.3471J) overall
#               This result is LIKELY reliable (p=0.0022)
#
# cpu_energy: mp_eas_nocgroups_interactive_w03,'eas' averaged less energy (25.9961J vs 21.4437J) overall
#             This result is NOT LIKELY reliable (p=0.0662)
#
# a53_cenr(BOARD_ENERGY_LITTLE): mp_eas_nocgroups_interactive_w03,'eas' averaged less energy (7.0978J vs 4.9986J) overall
#                                This result is LIKELY reliable (p=0.0022)
#
# a57_cenr(BOARD_ENERGY_BIG): mp_eas_nocgroups_interactive_w03,'eas' averaged less energy (18.8983J vs 16.4451J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_w03(hmp) mp_eas_nocgroups_interactive_w03(eas)
# total_energy(mean)                                            82.7837                  70.3471
# total_energy(stdev)                                            1.7004                   3.9824
# cpu_energy(mean)                                              25.9961                  21.4437
# cpu_energy(stdev)                                              0.7810                   3.0515
# a53_cenr(BOARD_ENERGY_LITTLE)(mean)                            7.0978                   4.9986
# a53_cenr(BOARD_ENERGY_LITTLE)(stdev)                           0.2865                   0.5974
# a57_cenr(BOARD_ENERGY_BIG)(mean)                              18.8983                  16.4451
# a57_cenr(BOARD_ENERGY_BIG)(stdev)                              0.6093                   2.4723
#
#
# There are 3 other Interesting Scores:
# gpu_cenr(BOARD_ENERGY_GPU): mp_eas_nocgroups_interactive_w03,'eas' averaged less energy (10.5415J vs 7.0901J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
# time sd: mp_eas_nocgroups_interactive_w03,'eas' averaged lower (0.0368 vs 0.0333) overall
#          This result is NOT LIKELY reliable (p=0.3913)
#
# sys_cenr(BOARD_ENERGY_SYS): mp_eas_nocgroups_interactive_w03,'eas' averaged less energy (46.2460J vs 41.8132J) overall
#                             This result is LIKELY reliable (p=0.0022)
#
#
# metric                                              mp_a53bc_w03(hmp) mp_eas_nocgroups_interactive_w03(eas)
# gpu_cenr(BOARD_ENERGY_GPU)(mean)                              10.5415                   7.0901
# gpu_cenr(BOARD_ENERGY_GPU)(stdev)                              0.1822                   0.1433
# time sd(mean)                                                  0.0368                   0.0333
# time sd(stdev)                                                 0.0097                   0.0134
# sys_cenr(BOARD_ENERGY_SYS)(mean)                              46.2460                  41.8132
# sys_cenr(BOARD_ENERGY_SYS)(stdev)                              1.1630                   0.9607
