# %% [markdown]
# # Summary plots

# %% [markdown]
# `cr2.summary_plots()` shows all the relevant (for the power allocator governor) plots for a particular run.

# %% [markdown]
# First some hacks to allow importing cr2 from here

# %%
import sys
sys.path.append("..")

# %%
# %pylab inline
import cr2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# For a description of `map_label` and `actor_order` see the compare runs notebook.

# %%
map_label = {"0000000f": "A7", "000000f0": "A15"}
actor_order = ["GPU", "A15", "A7"]

# %% [markdown]
# `actor_order` is an array that with the order in which the actors appear in the `thermal_power_allocator` tracepoint.

# %%
cr2.summary_plots(actor_order, map_label, path="../tests")
